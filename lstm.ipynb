# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import pickle
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Embedding, GlobalAveragePooling1D, LSTM, Input, Dropout, Bidirectional
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_csv("./output/data_clean.csv")

df.sample()
# Out:
#                          content  score                  text_clean  \
# 3871  cepat mudah dan bermanfaat      5  cepat mudah dan bermanfaat
#
#             text_casefoldingText             text_slangwords  \
# 3871  cepat mudah dan bermanfaat  cepat mudah dan bermanfaat
#
#                           text_tokenizingText  \
# 3871  ['cepat', 'mudah', 'dan', 'bermanfaat']
#
#                          text_stopword              text_final  \
# 3871  ['cepat', 'mudah', 'bermanfaat']  cepat mudah bermanfaat
#
#       polarity_score  polarity
# 3871              12  positive

# %% [markdown]
# ### Data Preprocessing
#
# Label Encoder to convert categorical label to numeric

# %%
label_encoder = preprocessing.LabelEncoder() 
df['polarity_encode'] = label_encoder.fit_transform(df['polarity'])

# %%
df.sample()
# Out:
#                                                  content  score  \
# 10340  Selalu upgrade tentang promosi atau info menar...      4
#
#                                               text_clean  \
# 10340  Selalu upgrade tentang promosi atau info menar...
#
#                                     text_casefoldingText  \
# 10340  selalu upgrade tentang promosi atau info menar...
#
#                                          text_slangwords  \
# 10340  selalu upgrade tentang promosi atau info menar...
#
#                                      text_tokenizingText  \
# 10340  ['selalu', 'upgrade', 'tentang', 'promosi', 'a...
#
#                                            text_stopword  \
# 10340  ['upgrade', 'promosi', 'info', 'menarik', 'apl...
#
#                                               text_final  polarity_score  \
# 10340  upgrade promosi info menarik aplikasi mudah fr...               4
#
#        polarity  polarity_encode
# 10340  positive                2

# %% [markdown]
# Tokenization

# %%
sentences = df['text_final'].astype(str).tolist()

tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index 

sequences = tokenizer.texts_to_sequences(sentences)

padded = pad_sequences(sequences, maxlen=100, padding='post', truncating='post')

# %%
with open('./assets/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df.sample()
# Out:
#                                                 content  score  \
# 2688  mempermudah kita yang malas belanja keluar rum...      5
#
#                                              text_clean  \
# 2688  mempermudah kita yang malas belanja keluar rum...
#
#                                    text_casefoldingText  \
# 2688  mempermudah kita yang malas belanja keluar rum...
#
#                                         text_slangwords  \
# 2688  mempermudah kita yang malas belanja keluar rum...
#
#                                     text_tokenizingText  \
# 2688  ['mempermudah', 'kita', 'yang', 'malas', 'bela...
#
#                                           text_stopword  \
# 2688  ['mempermudah', 'malas', 'belanja', 'rumah', '...
#
#                                  text_final  polarity_score  polarity  \
# 2688  mempermudah malas belanja rumah keren               1  positive
#
#       polarity_encode
# 2688                2

# %%
dataset = df.values

# %%
X_input = np.array(padded).astype('float32')
y_input = np.array(dataset[:,10]).astype('float32')

# %% [markdown]
# Feature Engineering: Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X_input, y_input)

print("Jumlah Data Setelah ROS:", len(X_resampled))
# Out:
# Jumlah Data Setelah ROS: 20118

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, stratify=y_resampled, test_size=0.3)

# %% [markdown]
# ### Modelling

# %% [markdown]
# LSTM model

# %%
model = Sequential([
    Input(shape=(100,)),
    Embedding(input_dim=5000, output_dim=128),

    Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.2)),

    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(3, activation='softmax')
])

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Callback checkpoint to save best model accuracy

# %%
checkpoint = ModelCheckpoint(
    './assets/best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/20
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - accuracy: 0.6524 - loss: 0.7680 - val_accuracy: 0.8644 - val_loss: 0.4300
# Epoch 2/20
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 29s 328ms/step - accuracy: 0.8910 - loss: 0.3301 - val_accuracy: 0.9088 - val_loss: 0.2677
# Epoch 3/20
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 29s 328ms/step - accuracy: 0.9389 - loss: 0.1891 - val_accuracy: 0.9414 - val_loss: 0.1888
# Epoch 4/20
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 29s 326ms/step - accuracy: 0.9604 - loss: 0.1293 - val_accuracy: 0.9471 - val_loss: 0.1691
# Epoch 5/20
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 29s 326ms/step - accuracy: 0.9698 - loss: 0.0991 - val_accuracy: 0.9368 - val_loss: 0.2162
# Epoch 6/20
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 29s 327ms/step - accuracy: 0.9791 - loss: 0.0700 - val_accuracy: 0.9489 - val_loss: 0.1988
# Epoch 7/20
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 29s 331ms/step - accuracy: 0.9834 - loss: 0.0557 - val_accuracy: 0.9531 - val_loss: 0.1822

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Model evaluation

# %%
model.evaluate(X_test, y_test, batch_size=1)
# Out:
# 6036/6036 ━━━━━━━━━━━━━━━━━━━━ 95s 16ms/step - accuracy: 0.9486 - loss: 0.1729
# [0.1728813648223877, 0.9486414790153503]
