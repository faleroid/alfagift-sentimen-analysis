# %%
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd

# %% [markdown]
# ## Data Collecting

# %% [markdown]
# Scrapping Alfagift App Reviews from Google Play

# %%
result, continuation_token = reviews(
    'com.alfamart.alfagift',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=12000,
)

# %%
df = pd.DataFrame(result)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              12000 non-null  object
#  1   userName              12000 non-null  object
#  2   userImage             12000 non-null  object
#  3   content               12000 non-null  object
#  4   score                 12000 non-null  int64
#  5   thumbsUpCount         12000 non-null  int64
#  6   reviewCreatedVersion  10307 non-null  object
#  7   at                    12000 non-null  datetime64[ns]
#  8   replyContent          4845 non-null   object
#  9   repliedAt             4845 non-null   datetime64[ns]
#  10  appVersion            10307 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.0+ MB

# %%
df.head()
# Out:
#                                reviewId         userName  \
# 0  2c95790f-c09a-48c3-bcee-8235e75f0469  Pengguna Google
# 1  def260dd-0bdd-4bc0-ab11-f0f013e8d172  Pengguna Google
# 2  26cc4714-f2b6-41bd-b840-72ff2e461bea  Pengguna Google
# 3  d2a24b7d-1bbc-41a2-ae4b-5864fb5ba650  Pengguna Google
# 4  3167c0b2-d328-4ee5-9886-9d94e7c5c46e  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  aneh banget sekarang, harga tertera pas di che...      1             17
# 1  Saat pembayaran aplikasi force close, pas buka...      2              4
# 2  Mungkin ini gimana cabangnya, tapi pesen masih...      1             18
# 3  saya pertama kali jadi member di alfa tapi saa...      2              3
# 4  mungkin harus ada pembaharuan di aplikasi, say...      3              2
#
#   reviewCreatedVersion                  at  \
# 0               4.46.0 2026-02-02 09:47:13
# 1               4.46.0 2026-01-29 14:25:28
# 2               4.46.0 2026-01-25 00:14:44
# 3               4.46.0 2026-01-26 10:44:21
# 4               4.46.0 2026-01-28 10:51:56
#
#                                         replyContent           repliedAt  \
# 0  Hai, Kak. Mohon maaf atas ketidaknyamanannya. ... 2026-02-02 21:17:20
# 1  Hi, Kak. Maaf banget ya buat kendalanya. Biar ... 2026-01-29 15:25:29
# 2  Hi, Kak. Mohon maaf atas ketidaknyamanannya. M... 2026-01-25 14:27:50
# 3  Hi, Kak, maaf banget ya buat kendalanya. Biar ... 2026-01-26 11:05:25
# 4  Hai, Kak. Terima kasih banyak atas masukan dan... 2026-01-28 11:53:36
#
#   appVersion
# 0     4.46.0
# 1     4.46.0
# 2     4.46.0
# 3     4.46.0
# 4     4.46.0

# %%
df.to_csv('df_alfagift.csv', index=False)
